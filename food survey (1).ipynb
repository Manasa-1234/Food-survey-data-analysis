# %%
#importing liberaries and collecting the downloaded data from downloads#

import pandas as pd
data = pd.read_csv('food servey.csv')

# %%
#To find the type of collected data weather it is a list or daraframe,html or etc.....#

type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Finding the length of the data#

len(data)
# Out:
# 24

# %%
#To find the contents of the data collected#

df.head(25)
# Out:
#             Timestamp Are you a Vegetarian or Non Vegetarian   \
# 0   1/7/2021 12:41:21                                     yes
# 1   1/7/2021 12:47:37                                      No
# 2   1/7/2021 12:48:43                                     yes
# 3   1/7/2021 12:49:36                                     yes
# 4   1/7/2021 12:49:42                                     yes
# 5   1/7/2021 12:52:33                                      No
# 6   1/7/2021 12:55:13                                      No
# 7   1/7/2021 12:57:22                                     yes
# 8   1/7/2021 12:57:27                                      No
# 9   1/7/2021 12:59:43                                     yes
# 10  1/7/2021 13:03:08                                      No
# 11  1/7/2021 13:05:29                                     yes
# 12  1/7/2021 13:15:44                                     NaN
# 13  1/7/2021 13:16:39                                     yes
# ...

# %%
#To find the none values the,cells with none values show True and cells with no none value show False#

df.isna()
# Out:
#     Timestamp  Are you a Vegetarian or Non Vegetarian   \
# 0       False                                    False
# 1       False                                    False
# 2       False                                    False
# 3       False                                    False
# 4       False                                    False
# 5       False                                    False
# 6       False                                    False
# 7       False                                    False
# 8       False                                    False
# 9       False                                    False
# 10      False                                    False
# 11      False                                    False
# 12      False                                     True
# 13      False                                    False
# 14      False                                    False
# 15      False                                    False
# ...

# %%
#To know the exact places with none values#


def check_for_nan(dframe) :
    nan_frame = dframe.isna()
    d_cols = dframe.columns
    
    nan_places = {}
    for col in d_cols:
        col_lvals = nan_frame[col].to_list()
        nan_indices = [index for index, val in enumerate(col_lvals) if val == True]
        if nan_indices:
            nan_places[col] = nan_indices
        else:
            nan_places[col] = None
                
            return nan_places

# %%
check_for_nan(dframe=df)
# Out:
# {'Timestamp': None}

# %%
#To know about the type of data weather it is object,flot or etc#

df.dtypes
# Out:
# Timestamp                                                   object
# Are you a Vegetarian or Non Vegetarian                      object
# Do you like preparing your own Food or Prepared by          object
# Do like Homemade Food or Restaurant Food                    object
# Which is your favorite Dish                                 object
# Do like to have Dessert s after having spicy foods          object
# Did you have any health issues after having outside food    object
# When did you have more of outside Food?                     object
# Do have a particular restaurant to visit                    object
# Are you a Foodie                                            object
# name                                                        object
# dtype: object

# %%
#Gives complete information about the data like memeory used class,rangeindex,data columns,dtypes#


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Timestamp                                                 24 non-null     object
#  1   Are you a Vegetarian or Non Vegetarian                    22 non-null     object
#  2   Do you like preparing your own Food or Prepared by        22 non-null     object
#  3   Do like Homemade Food or Restaurant Food                  23 non-null     object
#  4   Which is your favorite Dish                               23 non-null     object
#  5   Do like to have Dessert s after having spicy foods        23 non-null     object
#  6   Did you have any health issues after having outside food  23 non-null     object
#  7   When did you have more of outside Food?                   23 non-null     object
# ...
